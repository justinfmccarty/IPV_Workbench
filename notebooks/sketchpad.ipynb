# %%
import pickle
import json
import os
from pprint import pprint
import numpy as np

# %%
list(range(0,1))
# Out:
# [0]

# %%
ipv_file = "/Users/jmccarty/Data/220726_vegetation_paper/EugenHuber2_2679_1248/panelizer/panelizer_2679_1248.pickle"
with open(ipv_file,"rb") as fp:
    ipv = pickle.load(fp)

# %%
pprint(ipv['BUILDING']['SURFACES']['Wall5'])
# Out:
# {'DETAILS': {'GROSSAREA': 41.68,
#              'NETAREA': None,
#              'NORMAL': (0.40385398525700306, 0.9148234576091915, -0.0),
#              'TYPE': 'Wall'},
#  'STRINGS': {'{5;0;0}': {'DETAILS': {'GROSSAREA': 2.02,
#                                      'MODULECOUNT': 2.0,
#                                      'TYPE': 'standard'},
#                          'MODULES': {'{5;0;0;0}': {'DETAILS': {'AREA': 1.0358437500001307,
#                                                                'CELLeff': None,
#                                                                'NORMAL': '0.403853985256988,0.914823457609198,-2.44356527270186E-12',
#                                                                'XYZ': '17.1051449162299,4.28495919964735,2.9901125861429'},
#                                                    'DIODEPATH': {'{5;0;0;0;0}': {'CELLSNORMAL': [[0.4039,
# ...
